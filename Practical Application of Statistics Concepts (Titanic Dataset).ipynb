# %% [markdown]
# Practical Application of Statistics Concepts (Titanic Dataset)
# For the titanic dataset, I have implemented the following topics using python:
# 1. Measure of Central Tendency
# 2. Measure of Dispersion
# 3. Five Point Summary
# 4. Box Plot
# 5. Histogram and Distribution
# 6. Standardization
# 7. Normalization
# 8. Central Limit Theorem
# 9. Covariance
# 10. Pearson correlation coefficient
# 11. Spearman's rank correlation coefficient
# 12. Hypothesis testing (z-test, z-test with proportions, t-test, chi-square test)
# Note: For hypothesis testing, I have done the manual calculations, in the coming post I’ll upload calculations using python libraries.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import statistics as stat
import matplotlib.pyplot as plt
import random

# %% [markdown]
# # 0.0 iris DataSet

# %%
df = sns.load_dataset('titanic')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# #### 0.1 Data Conversion and Numerical Dataset

# %%
# Converting 'class' column values to integer and type from 'category' to 'int64'

df['class'] = df['class'].replace('First', '1').replace('Second', '2').replace('Third', '3')
df['class'] = df['class'].astype('int64')

# %%
# Converting alone values to integer and type from bool to int64

df['alone'] = df['alone'].replace('True', '1').replace('False', '2')
df['alone'] = df['alone'].astype('int64')

# %%
df_num = df[df.dtypes[df.dtypes != 'object'].index]

# %%
# dropping unnecessary column adult_male and deck

df_num.drop(columns=['adult_male', 'deck'], axis=1, inplace=True)
# Out:
# C:\Users\Sai\anaconda3\lib\site-packages\pandas\core\frame.py:4305: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df_num.head()
# Out:
#    survived  pclass   age  sibsp  parch     fare  class  alone
# 0         0       3  22.0      1      0   7.2500      3      0
# 1         1       1  38.0      1      0  71.2833      1      0
# 2         1       3  26.0      0      0   7.9250      3      1
# 3         1       1  35.0      1      0  53.1000      1      0
# 4         0       3  35.0      0      0   8.0500      3      1

# %% [markdown]
# #### Observation :
#
# - Unnecessary columns are removed

# %% [markdown]
# #### Checking dataset for NAN values

# %%
df_num.isnull().sum()
# Out:
# survived      0
# pclass        0
# age         177
# sibsp         0
# parch         0
# fare          0
# class         0
# alone         0
# dtype: int64

# %% [markdown]
# Observation :
# - There are nan values in 'age' feature

# %% [markdown]
# #### 0.3 Mean and Median of Age

# %%
np.mean(df_num['age'])
# Out:
# 29.69911764705882

# %%
np.median(df_num['age'])
# Out:
# nan

# %% [markdown]
# #### Observation :
# - Mean is a numeric value
# - Median is nan

# %% [markdown]
# #### 0.4 Boxplot for checking outliers

# %%
sns.set(rc={'figure.figsize':(15,5)})
sns.boxplot(data=df_num['age'], orient='h')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Observation :
# - Since age column containn outliers it is better to use median to fill the NAN values but median of age is nan itself so using mean of age to fill NAN values

# %% [markdown]
# #### 0.5 Replacing NAN values with mean

# %%
df_num['age'].fillna(np.mean(df_num['age']), inplace=True)

# %%
df_num['age'].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### Observation :
# - All the null values got replaced

# %%
df_num.isnull().sum()
# Out:
# survived    0
# pclass      0
# age         0
# sibsp       0
# parch       0
# fare        0
# class       0
# alone       0
# dtype: int64

# %% [markdown]
# # 1.0 Measure of Central Tendency

# %% [markdown]
# ### 1.1 Mean of all numerical columns

# %%
np.mean(df_num, axis=0)
# Out:
# survived     0.383838
# pclass       2.308642
# age         29.699118
# sibsp        0.523008
# parch        0.381594
# fare        32.204208
# class        2.308642
# alone        0.602694
# dtype: float64

# %% [markdown]
# ### 1.2 Median of all numeric colimns

# %%
np.median(df_num, axis=0)
# Out:
# array([ 0.        ,  3.        , 29.69911765,  0.        ,  0.        ,
#        14.4542    ,  3.        ,  1.        ])

# %% [markdown]
# ### 1.3 Mode of all the columns

# %%
df.mode()
# Out:
#    survived  pclass   sex   age  sibsp  parch  fare embarked  class  who  \
# 0         0       3  male  24.0      0      0  8.05        S      3  man
#
#    adult_male deck  embark_town alive  alone
# 0        True    C  Southampton    no      1

# %%
# For individual column

stat.mode(df_num['age'])
# Out:
# 29.69911764705882

# %% [markdown]
# ## 2.0 Measure of dispersion

# %% [markdown]
# ### 2.1 Variance

# %%
# For all the columns

df_num.var()
# Out:
# survived       0.236772
# pclass         0.699015
# age          169.052400
# sibsp          1.216043
# parch          0.649728
# fare        2469.436846
# class          0.699015
# alone          0.239723
# dtype: float64

# %%
# For individual column

stat.variance(df_num['age'])
# Out:
# 169.05239993721082

# %% [markdown]
# ### 2.2 Standard deviation

# %%
df_num.std()
# Out:
# survived     0.486592
# pclass       0.836071
# age         13.002015
# sibsp        1.102743
# parch        0.806057
# fare        49.693429
# class        0.836071
# alone        0.489615
# dtype: float64

# %%
# For individual column

stat.stdev(df_num['age'])
# Out:
# 13.002015226002884

# %% [markdown]
# # 3.0 Five point Summary

# %% [markdown]
# #### 3.1 For survived column

# %%
print("Minimum value is: {}".format(df_num['survived'].min())) # zeroth Percentile or minimum value
print("1st quartile is: {}".format(np.percentile(df_num['survived'], 25))) # 1st quartile
print("Median is: {}".format(np.percentile(df_num['survived'], 50))) # 2nd quartile or median
print("3rd quartile is: {}".format(np.percentile(df_num['survived'], 75))) # 3rd quartile
print("Maximum value is: {}".format(df_num['survived'].max())) # 100th Percentile or maximum value
# Out:
# Minimum value is: 0
# 1st quartile is: 0.0
# Median is: 0.0
# 3rd quartile is: 1.0
# Maximum value is: 1

# %% [markdown]
# #### 3.2 For pclass column

# %%
print('Minimum value is : {}'.format(df_num['pclass'].min()))
print('1st quartile is : {}'.format(np.percentile(df_num['pclass'], 25)))
print('Median is : {}'.format(np.percentile(df_num['pclass'], 50)))
print('3rd quartile is : {}'.format(np.percentile(df_num['pclass'], 75)))
print('Maximum value is : {}'.format(df_num['pclass'].max()))
# Out:
# Minimum value is : 1
# 1st quartile is : 2.0
# Median is : 3.0
# 3rd quartile is : 3.0
# Maximum value is : 3

# %% [markdown]
# #### 3.3 For age column

# %%
print("Minimum value is: {}".format(df_num['age'].min()))
print("1st quartile is: {}".format(np.percentile(df_num['age'], 25)))
print("Median is: {}".format(np.percentile(df_num['age'], 50)))
print("3rd quartile is: {}".format(np.percentile(df_num['age'], 75)))
print("Maximum value is: {}".format(df_num['age'].max()))
# Out:
# Minimum value is: 0.42
# 1st quartile is: 22.0
# Median is: 29.69911764705882
# 3rd quartile is: 35.0
# Maximum value is: 80.0

# %% [markdown]
# #### 3.4 For sibsp (Siblings) Column

# %%
print("Minimum value is: {}".format(df_num['sibsp'].min()))
print("1st quartile is: {}".format(np.percentile(df_num['sibsp'], 25)))
print("Median is: {}".format(np.percentile(df_num['sibsp'], 50)))
print("3rd quartile is: {}".format(np.percentile(df_num['sibsp'], 75)))
print("Maximum value is: {}".format(df_num['sibsp'].max()))
# Out:
# Minimum value is: 0
# 1st quartile is: 0.0
# Median is: 0.0
# 3rd quartile is: 1.0
# Maximum value is: 8

# %% [markdown]
# #### 3.5 For parch (parent-child) Column

# %%
print("Minimum value is: {}".format(df_num['parch'].min()))
print("1st quartile is: {}".format(np.percentile(df_num['parch'], 25)))
print("Median is: {}".format(np.percentile(df_num['parch'], 50)))
print("3rd quartile is: {}".format(np.percentile(df_num['parch'], 75)))
print("Maximum value is: {}".format(df_num['parch'].max()))
# Out:
# Minimum value is: 0
# 1st quartile is: 0.0
# Median is: 0.0
# 3rd quartile is: 0.0
# Maximum value is: 6

# %% [markdown]
# #### 3.6 For fare Column

# %%
print("Minimum value is: {}".format(df_num['fare'].min()))
print("1st quartile is: {}".format(np.percentile(df_num['fare'], 25)))
print("Median is: {}".format(np.percentile(df_num['fare'], 50)))
print("3rd quartile is: {}".format(np.percentile(df_num['fare'], 75)))
print("Maximum value is: {}".format(df_num['fare'].max()))
# Out:
# Minimum value is: 0.0
# 1st quartile is: 7.9104
# Median is: 14.4542
# 3rd quartile is: 31.0
# Maximum value is: 512.3292

# %% [markdown]
# #### 3.7 For class Column

# %%
print("Minimum value is: {}".format(df_num['class'].min()))
print("1st quartile is: {}".format(np.percentile(df_num['class'], 25)))
print("Median is: {}".format(np.percentile(df_num['class'], 50)))
print("3rd quartile is: {}".format(np.percentile(df_num['class'], 75)))
print("Maximum value is: {}".format(df_num['class'].max()))
# Out:
# Minimum value is: 1
# 1st quartile is: 2.0
# Median is: 3.0
# 3rd quartile is: 3.0
# Maximum value is: 3

# %% [markdown]
# #### 3.8 For alone Column

# %%
print("Minimum value is: {}".format(df_num['alone'].min()))
print("1st quartile is: {}".format(np.percentile(df_num['alone'], 25)))
print("Median is: {}".format(np.percentile(df_num['alone'], 50)))
print("3rd quartile is: {}".format(np.percentile(df_num['alone'], 75)))
print("Maximum value is: {}".format(df_num['alone'].max()))
# Out:
# Minimum value is: 0
# 1st quartile is: 0.0
# Median is: 1.0
# 3rd quartile is: 1.0
# Maximum value is: 1

# %% [markdown]
# # 4.0 Boxplot

# %% [markdown]
# ### 4.1 Box plot for survived

# %%
sns.set(rc={'figure.figsize':(15,5)})
sns.boxplot(data=df_num['survived'], orient="h")
# Out:
# <AxesSubplot:>

# %% [markdown]
# Observation :
# -

# %% [markdown]
# ### 4.2 Box plot for pclass

# %%
sns.set(rc={'figure.figsize': (15,5)})
sns.boxplot(data=df_num['pclass'], orient='h')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Observation :
# - pclass has maximum point same as 3rd quartile

# %% [markdown]
# ### 4.3 Box plot for age

# %%
sns.set(rc={'figure.figsize':(15,5)})
sns.boxplot(data=df_num['age'], orient="h")
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Observation :
# - age feature has outliers in the right hand side of the plot

# %% [markdown]
# ### 4.4 Box plot for sibsp

# %%
sns.set(rc={'figure.figsize':(15,5)})
sns.boxplot(data=df_num['sibsp'], orient="h")
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### AObservation :
# - sibsp feature has outliers in the right hand side of the plot

# %% [markdown]
# ### 4.5 Box plot for parch

# %%
sns.set(rc={'figure.figsize':(15,5)})
sns.boxplot(data=df_num['parch'], orient="h")
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Observation :
# - parch feature has more outliers

# %% [markdown]
# ### 4.6 Box plot for fare

# %%
sns.set(rc={'figure.figsize':(15,5)})
sns.boxplot(data=df_num['fare'], orient="h")
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### AObservation :
# - fare feature has outliers in the right hand side.

# %% [markdown]
# ### 4.7 Box plot for class

# %%
sns.set(rc={'figure.figsize':(15,5)})
sns.boxplot(data=df_num['class'], orient="h")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 4.8 Box plot for alone

# %%
sns.set(rc={'figure.figsize':(15,5)})
sns.boxplot(data=df_num['alone'], orient="h")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 5.0 Histogram and Distribution

# %% [markdown]
# ### 5.1 Histogram and Distribution for survived

# %%
sns.histplot(data=df_num['survived'], kde=True)
# Out:
# <AxesSubplot:xlabel='survived', ylabel='Count'>

# %% [markdown]
# ### 5.2 Histogram and Distribution for pclass

# %%
sns.histplot(data=df_num['pclass'], kde=True)
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='Count'>

# %% [markdown]
# ### 5.3 Histogram and Distribution for age

# %%
sns.histplot(data=df_num['age'], kde=True)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %% [markdown]
# #### Observation :
# - age feature follows gaussian distribution

# %% [markdown]
# ### 5.4 Histogram and Distribution for sibsp

# %%
sns.histplot(data=df_num['sibsp'], kde=True)
# Out:
# <AxesSubplot:xlabel='sibsp', ylabel='Count'>

# %% [markdown]
# ### 5.5 Histogram and Distribution for parch

# %%
 sns.histplot(data=df_num['parch'], kde=True)
# Out:
# <AxesSubplot:xlabel='parch', ylabel='Count'>

# %% [markdown]
# ### 5.6 Histogram and Distribution for fare

# %%
sns.histplot(data=df_num['fare'], kde=True)
# Out:
# <AxesSubplot:xlabel='fare', ylabel='Count'>

# %% [markdown]
# ### 5.7 Histogram and Distribution for class

# %%
sns.histplot(data=df_num['class'], kde=True)
# Out:
# <AxesSubplot:xlabel='class', ylabel='Count'>

# %% [markdown]
# ### 5.8 Histogram and Distribution for alone

# %%
 sns.histplot(data=df_num['alone'], kde=True)
# Out:
# <AxesSubplot:xlabel='alone', ylabel='Count'>

# %% [markdown]
# ## 6.0 Standardization

# %%
df_num.head()
# Out:
#    survived  pclass   age  sibsp  parch     fare  class  alone
# 0         0       3  22.0      1      0   7.2500      3      0
# 1         1       1  38.0      1      0  71.2833      1      0
# 2         1       3  26.0      0      0   7.9250      3      1
# 3         1       1  35.0      1      0  53.1000      1      0
# 4         0       3  35.0      0      0   8.0500      3      1

# %% [markdown]
# ## 6.1 standardization of dataset

# %%
df_standard = (df_num - df_num.mean())/df_num.std()
df_standard.head()
# Out:
#    survived    pclass       age     sibsp     parch      fare     class  \
# 0 -0.788829  0.826913 -0.592148  0.432550 -0.473408 -0.502163  0.826913
# 1  1.266279 -1.565228  0.638430  0.432550 -0.473408  0.786404 -1.565228
# 2  1.266279  0.826913 -0.284503 -0.474279 -0.473408 -0.488580  0.826913
# 3  1.266279 -1.565228  0.407697  0.432550 -0.473408  0.420494 -1.565228
# 4 -0.788829  0.826913  0.407697 -0.474279 -0.473408 -0.486064  0.826913
#
#       alone
# 0 -1.230954
# 1 -1.230954
# 2  0.811467
# 3 -1.230954
# 4  0.811467

# %% [markdown]
# ### 6.2 mean and standard deviation of standardized dataset

# %%
round(df_standard.mean())
# Out:
# survived    0.0
# pclass      0.0
# age         0.0
# sibsp       0.0
# parch      -0.0
# fare        0.0
# class       0.0
# alone       0.0
# dtype: float64

# %%
df_standard.std()
# Out:
# survived    1.0
# pclass      1.0
# age         1.0
# sibsp       1.0
# parch       1.0
# fare        1.0
# class       1.0
# alone       1.0
# dtype: float64

# %% [markdown]
# #### Observation :
# - standardized dataset feature has mean 0 and standard deviation 1

# %% [markdown]
# ### 6.3 kde plot of original dataset

# %%
sns.kdeplot(data=df)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.kdeplot(data=df_num[['survived', 'pclass', 'sibsp', 'parch', 'class', 'alone']])
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.kdeplot(data=df_num[['age', 'fare']])
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ### 6.4 kde plot of standardized dataset

# %%
sns.kdeplot(data=df_standard)
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ## 7.0 Normalization

# %% [markdown]
# #### Using MinMax Scalar

# %% [markdown]
# #### Note: using MinMax Scalar the data range will be 0 to 1.

# %%
df_num.head()
# Out:
#    survived  pclass   age  sibsp  parch     fare  class  alone
# 0         0       3  22.0      1      0   7.2500      3      0
# 1         1       1  38.0      1      0  71.2833      1      0
# 2         1       3  26.0      0      0   7.9250      3      1
# 3         1       1  35.0      1      0  53.1000      1      0
# 4         0       3  35.0      0      0   8.0500      3      1

# %% [markdown]
# ### 7.1 normalization of dataset

# %%
df_normal = (df_num - df_num.min())/(df_num.max() - df_num.min())
df_normal.head()
# Out:
#    survived  pclass       age  sibsp  parch      fare  class  alone
# 0       0.0     1.0  0.271174  0.125    0.0  0.014151    1.0    0.0
# 1       1.0     0.0  0.472229  0.125    0.0  0.139136    0.0    0.0
# 2       1.0     1.0  0.321438  0.000    0.0  0.015469    1.0    1.0
# 3       1.0     0.0  0.434531  0.125    0.0  0.103644    0.0    0.0
# 4       0.0     1.0  0.434531  0.000    0.0  0.015713    1.0    1.0

# %% [markdown]
# ### 7.2 min, max, mean and standard deviation of normalized dataset

# %%
df_normal.min()
# Out:
# survived    0.0
# pclass      0.0
# age         0.0
# sibsp       0.0
# parch       0.0
# fare        0.0
# class       0.0
# alone       0.0
# dtype: float64

# %%
df_normal.max()
# Out:
# survived    1.0
# pclass      1.0
# age         1.0
# sibsp       1.0
# parch       1.0
# fare        1.0
# class       1.0
# alone       1.0
# dtype: float64

# %%
df_normal.mean()
# Out:
# survived    0.383838
# pclass      0.654321
# age         0.367921
# sibsp       0.065376
# parch       0.063599
# fare        0.062858
# class       0.654321
# alone       0.602694
# dtype: float64

# %%
df_normal.std()
# Out:
# survived    0.486592
# pclass      0.418036
# age         0.163383
# sibsp       0.137843
# parch       0.134343
# fare        0.096995
# class       0.418036
# alone       0.489615
# dtype: float64

# %% [markdown]
# #### Observation :
# - Here our dataset is ranging between 0 to 1.

# %% [markdown]
# ### 7.3 kde plot of original dataset

# %%
 sns.kdeplot(data=df_num[['survived', 'pclass', 'sibsp', 'parch', 'class', 'alone']])
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.kdeplot(data=df_num[['age', 'fare']])
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ### 7.4 kde plot of normalized dataset

# %%
sns.kdeplot(data=df_normal)
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# # 8.0 Central Limit Theorem

# %% [markdown]
# #### The Central Limit Theorem(CLT) states that for any data, provided a high number of samples have been taken. The following properties hold:
#
# 1. Sampling Distribution Mean(μₓ¯) = Population Mean(μ)
# 2. Sampling distribution’s standard deviation (Standard error) = σ/√n ≈S/√n
# 3. For n > 30, the sampling distribution becomes a normal distribution.

# %%
df_num.head()
# Out:
#    survived  pclass   age  sibsp  parch     fare  class  alone
# 0         0       3  22.0      1      0   7.2500      3      0
# 1         1       1  38.0      1      0  71.2833      1      0
# 2         1       3  26.0      0      0   7.9250      3      1
# 3         1       1  35.0      1      0  53.1000      1      0
# 4         0       3  35.0      0      0   8.0500      3      1

# %% [markdown]
# ### 8.1 For survived column

# %% [markdown]
# #### 8.1.1 Population Mean and Standard Deviation

# %%
mean_pop_survived = df_num['survived'].mean()
std_pop_survived = df_num['survived'].std()
print("population mean (μ): {}\npopulation standard deviation (σ): {}".format(mean_pop_survived,std_pop_survived))
# Out:
# population mean (μ): 0.3838383838383838
# population standard deviation (σ): 0.4865924542648585

# %% [markdown]
# #### 8.1.2 histplot

# %%
sns.set(rc={'figure.figsize':(12,5)})
sns.histplot(df_num['survived'], kde=True)
# Out:
# <AxesSubplot:xlabel='survived', ylabel='Count'>

# %% [markdown]
# #### 8.1.3 Verifying CLT
# ##### 8.1.3.1 Keeping No. of Samples Constant

# %%
sample_sizes = [(500,3), (500,10), (500,30), (500,50), (500,100), (500,200)]
list_sample_means = []
# Plotting the distribution graphs for the above created Samples
plt.figure(figsize=[15,10])
for ind, (no_of_samples,samp_size) in enumerate(sample_sizes):
     sample_means = [df_num.survived.sample(samp_size).mean() for i in range(no_of_samples)]
     list_sample_means.append(sample_means)
     plt.subplot(2,3,ind+1)
     sns.histplot(sample_means, bins=25, kde=True, stat="density")
     plt.title("No. of Samples: "+str(no_of_samples) + " Sample size: "+str(samp_size))

# %%
for i in list_sample_means:
     print(pd.Series(i).mean())
# Out:
# 0.3740000000000002
# 0.38780000000000064
# 0.3882000000000014
# 0.38543999999999984
# 0.38342000000000015
# 0.38323999999999986

# %% [markdown]
# ##### 8.1.3.2 Keeping Samples Size Constant

# %%
sample_sizes = [(50,30), (100,30), (150,30), (200,30), (250,30), (300,30)]
list_sample_means = []

# Plotting the distribution graphs for the above created Samples
plt.figure(figsize=[15,10])
for ind, (no_of_samples,samp_size) in enumerate(sample_sizes):
     sample_means = [df_num.survived.sample(samp_size).mean() for i in range(no_of_samples)]
     list_sample_means.append(sample_means)
     plt.subplot(2,3,ind+1)
     sns.histplot(sample_means, bins=25, kde=True, stat="density")
     plt.title("No. of Samples: "+str(no_of_samples) + " Sample size: "+str(samp_size))

# %%
for i in list_sample_means:
     print(pd.Series(i).mean())
# Out:
# 0.3946666666666668
# 0.38799999999999985
# 0.3806666666666665
# 0.373333333333333
# 0.38959999999999956
# 0.38166666666666615

# %% [markdown]
# ### 8.2 For pclass column

# %% [markdown]
# #### 8.2.1 Population Mean and Standard Deviation

# %%
mean_pop_pclass = df_num['pclass'].mean()
std_pop_pclass = df_num['pclass'].std()
print("population mean (μ): {}\npopulation standard deviation (σ): {}".format(mean_pop_pclass,std_pop_pclass))
# Out:
# population mean (μ): 2.308641975308642
# population standard deviation (σ): 0.8360712409770513

# %% [markdown]
# #### 8.2.2 histplot

# %%
sns.set(rc={'figure.figsize':(12,5)})
sns.histplot(df_num['pclass'], kde=True)
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='Count'>

# %% [markdown]
# ### 8.2.3 Verifying CLT
# #### 8.2.3.1 Keeping No. of Samples Constant

# %%
sample_sizes = [(500,3), (500,10), (500,30), (500,50), (500,100), (500,200)]
list_sample_means = []
# Plotting the distribution graphs for the above created Samples
plt.figure(figsize=[15,10])
for ind, (no_of_samples,samp_size) in enumerate(sample_sizes):
     sample_means = [df_num.pclass.sample(samp_size).mean() for i in range(no_of_samples)]
     list_sample_means.append(sample_means)
     plt.subplot(2,3,ind+1)
     sns.histplot(sample_means, bins=25, kde=True, stat="density")
     plt.title("No. of Samples: "+str(no_of_samples) + " Sample size: "+str(samp_size))

# %%
for i in list_sample_means:
     print(pd.Series(i).mean())
# Out:
# 2.3353333333333337
# 2.3296000000000006
# 2.313133333333332
# 2.3116400000000006
# 2.3031199999999985
# 2.3092099999999998

# %% [markdown]
# #### 8.2.3.2 Keeping Samples Size Constant

# %%
sample_sizes = [(50,30), (100,30), (150,30), (200,30), (250,30), (300,30)]
list_sample_means = []
# Plotting the distribution graphs for the above created Samples
plt.figure(figsize=[15,10])
for ind, (no_of_samples,samp_size) in enumerate(sample_sizes):
     sample_means = [df_num.pclass.sample(samp_size).mean() for i in range(no_of_samples)]
     list_sample_means.append(sample_means)
     plt.subplot(2,3,ind+1)
     sns.histplot(sample_means, bins=25, kde=True, stat="density")
     plt.title("No. of Samples: "+str(no_of_samples) + " Sample size: "+str(samp_size))

# %%
for i in list_sample_means:
     print(pd.Series(i).mean())
# Out:
# 2.292666666666666
# 2.3323333333333336
# 2.306
# 2.3279999999999994
# 2.293199999999997
# 2.3239999999999994

# %% [markdown]
# ### 8.3 For age column
# #### 8.3.1 Population Mean and Standard Deviation

# %%
mean_pop_age = df_num['age'].mean()
std_pop_age = df_num['age'].std()
print("population mean (μ): {}\npopulation standard deviation (σ): {}".format(mean_pop_age,std_pop_age))
# Out:
# population mean (μ): 29.699117647058763
# population standard deviation (σ): 13.002015226002884

# %% [markdown]
# #### 8.3.2 histplot

# %%
sns.set(rc={'figure.figsize':(12,5)})
sns.histplot(df_num['age'], kde=True)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %% [markdown]
# ### 8.3.3 Verifying CLT
# #### 8.3.3.1 Keeping No. of Samples Constant

# %%
sample_sizes = [(500,3), (500,10), (500,30), (500,50), (500,100), (500,200)]
list_sample_means = []
# Plotting the distribution graphs for the above created Samples
plt.figure(figsize=[15,10])
for ind, (no_of_samples,samp_size) in enumerate(sample_sizes):
     sample_means = [df_num.age.sample(samp_size).mean() for i in range(no_of_samples)]
     list_sample_means.append(sample_means)
     plt.subplot(2,3,ind+1)
     sns.histplot(sample_means, bins=25, kde=True, stat="density")
     plt.title("No. of Samples: "+str(no_of_samples) + " Sample size: "+str(samp_size))

# %%
for i in list_sample_means:
     print(pd.Series(i).mean())
# Out:
# 29.634709999999984
# 29.73175435294118
# 29.61164735294116
# 29.863343023529406
# 29.710857776470586
# 29.645129685294137

# %% [markdown]
# #### 8.3.3.2 Keeping Samples Size Constant

# %%
sample_sizes = [(50,30), (100,30), (150,30), (200,30), (250,30), (300,30)]
list_sample_means = []
# Plotting the distribution graphs for the above created Samples
plt.figure(figsize=[15,10])
for ind, (no_of_samples,samp_size) in enumerate(sample_sizes):
     sample_means = [df_num.age.sample(samp_size).mean() for i in range(no_of_samples)]
     list_sample_means.append(sample_means)
     plt.subplot(2,3,ind+1)
     sns.histplot(sample_means, bins=25, kde=True, stat="density")
     plt.title("No. of Samples: "+str(no_of_samples) + " Sample size: "+str(samp_size))

# %%
for i in list_sample_means:
     print(pd.Series(i).mean())
# Out:
# 29.91109176470588
# 29.717330196078432
# 29.847047647058833
# 29.64535147058823
# 29.905610549019617
# 29.856658692810452

# %% [markdown]
# ### 8.4 For sibsp column
# #### 8.4.1 Population Mean and Standard Deviation

# %%
mean_pop_sibsp = df_num['sibsp'].mean()
std_pop_sibsp = df_num['sibsp'].std()
print("population mean (μ): {}\npopulation standard deviation (σ): {}".format(mean_pop_sibsp,std_pop_sibsp))
# Out:
# population mean (μ): 0.5230078563411896
# population standard deviation (σ): 1.1027434322934275

# %% [markdown]
# #### 8.4.2 histplot

# %%
sns.set(rc={'figure.figsize':(12,5)})
sns.histplot(df_num['sibsp'], kde=True)
# Out:
# <AxesSubplot:xlabel='sibsp', ylabel='Count'>

# %% [markdown]
# ### 8.4.3 Verifying CLT
# #### 8.4.3.1 Keeping No. of Samples Constant

# %%
sample_sizes = [(500,3), (500,10), (500,30), (500,50), (500,100), (500,200)]
list_sample_means = []
# Plotting the distribution graphs for the above created Samples
plt.figure(figsize=[15,10])
for ind, (no_of_samples,samp_size) in enumerate(sample_sizes):
     sample_means = [df_num.sibsp.sample(samp_size).mean() for i in range(no_of_samples)]
     list_sample_means.append(sample_means)
     plt.subplot(2,3,ind+1)
     sns.histplot(sample_means, bins=25, kde=True, stat="density")
     plt.title("No. of Samples: "+str(no_of_samples) + " Sample size: "+str(samp_size))

# %%
for i in list_sample_means:
     print(pd.Series(i).mean())
# Out:
# 0.5173333333333343
# 0.5119999999999993
# 0.5276000000000006
# 0.5228799999999999
# 0.5170200000000001
# 0.5285500000000005

# %% [markdown]
# #### 8.4.3.2 Keeping Samples Size Constant

# %%
sample_sizes = [(50,30), (100,30), (150,30), (200,30), (250,30), (300,30)]
list_sample_means = []
# Plotting the distribution graphs for the above created Samples
plt.figure(figsize=[15,10])
for ind, (no_of_samples,samp_size) in enumerate(sample_sizes):
     sample_means = [df_num.sibsp.sample(samp_size).mean() for i in range(no_of_samples)]
     list_sample_means.append(sample_means)
     plt.subplot(2,3,ind+1)
     sns.histplot(sample_means, bins=25, kde=True, stat="density")
     plt.title("No. of Samples: "+str(no_of_samples) + " Sample size: "+str(samp_size))

# %%
for i in list_sample_means:
     print(pd.Series(i).mean())
# Out:
# 0.5280000000000001
# 0.5039999999999997
# 0.5566666666666668
# 0.5093333333333332
# 0.5242666666666669
# 0.5100000000000005

# %% [markdown]
# ### 8.5 For parch column
# #### 8.5.1 Population Mean and Standard Deviation

# %%
mean_pop_parch = df_num['parch'].mean()
std_pop_parch = df_num['parch'].std()

print("population mean (μ): {}\npopulation standard deviation (σ): {}".format(mean_pop_parch,std_pop_parch))
# Out:
# population mean (μ): 0.38159371492704824
# population standard deviation (σ): 0.8060572211299559

# %% [markdown]
# #### 8.5.2 histplot

# %%
sns.set(rc={'figure.figsize':(12,5)})
sns.histplot(df_num['parch'], kde=True)
# Out:
# <AxesSubplot:xlabel='parch', ylabel='Count'>

# %% [markdown]
# #### 8.5.3 Verifying CLT
# #### 8.5.3.1 Keeping No. of Samples Constant

# %%
sample_sizes = [(500,3), (500,10), (500,30), (500,50), (500,100), (500,200)]
list_sample_means = []
# Plotting the distribution graphs for the above created Samples
plt.figure(figsize=[15,10])
for ind, (no_of_samples,samp_size) in enumerate(sample_sizes):
     sample_means = [df_num.parch.sample(samp_size).mean() for i in range(no_of_samples)]
     list_sample_means.append(sample_means)
     plt.subplot(2,3,ind+1)
     sns.histplot(sample_means, bins=25, kde=True, stat="density")
     plt.title("No. of Samples: "+str(no_of_samples) + " Sample size: "+str(samp_size))

# %%
for i in list_sample_means:
     print(pd.Series(i).mean())
# Out:
# 0.3826666666666665
# 0.3794000000000001
# 0.3846000000000009
# 0.37896000000000035
# 0.37659999999999966
# 0.38079000000000024

# %% [markdown]
# #### 8.5.3.2 Keeping Samples Size Constant

# %%
sample_sizes = [(50,30), (100,30), (150,30), (200,30), (250,30), (300,30)]
list_sample_means = []
# Plotting the distribution graphs for the above created Samples
plt.figure(figsize=[15,10])
for ind, (no_of_samples,samp_size) in enumerate(sample_sizes):
     sample_means = [df_num.parch.sample(samp_size).mean() for i in range(no_of_samples)]
     list_sample_means.append(sample_means)
     plt.subplot(2,3,ind+1)
     sns.histplot(sample_means, bins=25, kde=True, stat="density")
     plt.title("No. of Samples: "+str(no_of_samples) + " Sample size: "+str(samp_size))

# %%
for i in list_sample_means:
     print(pd.Series(i).mean())
# Out:
# 0.3993333333333334
# 0.3726666666666666
# 0.37599999999999995
# 0.3829999999999996
# 0.3745333333333333
# 0.38544444444444426

# %% [markdown]
# ### 8.6 for fare column
# #### 8.6.1 Population Mean and Standard Deviation

# %%
mean_pop_fare = df_num['fare'].mean()
std_pop_fare = df_num['fare'].std()
print("population mean (μ): {}\npopulation standard deviation (σ): {}".format(mean_pop_fare,std_pop_fare))
# Out:
# population mean (μ): 32.2042079685746
# population standard deviation (σ): 49.693428597180905

# %% [markdown]
# #### 8.6.2 histplot

# %%
sns.set(rc={'figure.figsize':(12,5)})
sns.histplot(df_num['fare'], kde=True)
# Out:
# <AxesSubplot:xlabel='fare', ylabel='Count'>

# %% [markdown]
# #### 8.6.3 Verifying CLT
# ##### 8.6.3.1 Keeping No. of Samples Constant

# %%
sample_sizes = [(500,3), (500,10), (500,30), (500,50), (500,100), (500,200)]
list_sample_means = []
# Plotting the distribution graphs for the above created Samples
plt.figure(figsize=[15,10])
for ind, (no_of_samples,samp_size) in enumerate(sample_sizes):
     sample_means = [df_num.fare.sample(samp_size).mean() for i in range(no_of_samples)]
     list_sample_means.append(sample_means)
     plt.subplot(2,3,ind+1)
     sns.histplot(sample_means, bins=25, kde=True, stat="density")
     plt.title("No. of Samples: "+str(no_of_samples) + " Sample size: "+str(samp_size))

# %%
for i in list_sample_means:
     print(pd.Series(i).mean())
# Out:
# 32.88710953333333
# 32.74738602000002
# 32.55056716666664
# 32.039770352000005
# 32.38511238200003
# 32.086497598000015

# %% [markdown]
# #### 8.6.3.2 Keeping Samples Size Constant

# %%
sample_sizes = [(50,30), (100,30), (150,30), (200,30), (250,30), (300,30)]
list_sample_means = []
# Plotting the distribution graphs for the above created Samples
plt.figure(figsize=[15,10])
for ind, (no_of_samples,samp_size) in enumerate(sample_sizes):
     sample_means = [df_num.fare.sample(samp_size).mean() for i in range(no_of_samples)]
     list_sample_means.append(sample_means)
     plt.subplot(2,3,ind+1)
     sns.histplot(sample_means, bins=25, kde=True, stat="density")
     plt.title("No. of Samples: "+str(no_of_samples) + " Sample size: "+str(samp_size))

# %%
for i in list_sample_means:
     print(pd.Series(i).mean())
# Out:
# 30.57629146666666
# 32.21953546666667
# 31.81543831111111
# 31.432222950000003
# 32.23686489333333
# 32.44154761111111

# %% [markdown]
# ### 8.7 for class column
# #### 8.7.1 Population Mean and Standard Deviation

# %%
mean_pop_class = df_num['class'].mean()
std_pop_class = df_num['class'].std()
print("population mean (μ): {}\npopulation standard deviation (σ): {}".format(mean_pop_class,std_pop_class))
# Out:
# population mean (μ): 2.308641975308642
# population standard deviation (σ): 0.8360712409770513

# %% [markdown]
# #### 8.7.2 histplot

# %%
sns.set(rc={'figure.figsize':(12,5)})
sns.histplot(df_num['class'], kde=True)
# Out:
# <AxesSubplot:xlabel='class', ylabel='Count'>

# %% [markdown]
# ### 8.7.3 Verifying CLT
# #### 8.7.3.1 Keeping No. of Samples Constant

# %%
sample_sizes = [(500,3), (500,10), (500,30), (500,50), (500,100), (500,200)]
list_sample_means = []
# Plotting the distribution graphs for the above created Samples
plt.figure(figsize=[15,10])
for ind, (no_of_samples,samp_size) in enumerate(sample_sizes):
     sample_means = [df_num['class'].sample(samp_size).mean() for i in range(no_of_samples)]
     list_sample_means.append(sample_means)
     plt.subplot(2,3,ind+1)
     sns.histplot(sample_means, bins=25, kde=True, stat="density")
     plt.title("No. of Samples: "+str(no_of_samples) + " Sample size: "+str(samp_size))

# %%
for i in list_sample_means:
     print(pd.Series(i).mean())
# Out:
# 2.296666666666667
# 2.3084000000000002
# 2.307399999999997
# 2.31528
# 2.3097199999999996
# 2.3076600000000003

# %%
sample_sizes = [(50,30), (100,30), (150,30), (200,30), (250,30), (300,30)]
list_sample_means = []
# Plotting the distribution graphs for the above created Samples
plt.figure(figsize=[15,10])
for ind, (no_of_samples,samp_size) in enumerate(sample_sizes):
     sample_means = [df_num['class'].sample(samp_size).mean() for i in range(no_of_samples)]
     list_sample_means.append(sample_means)
     plt.subplot(2,3,ind+1)
     sns.histplot(sample_means, bins=25, kde=True, stat="density")
     plt.title("No. of Samples: "+str(no_of_samples) + " Sample size: "+str(samp_size))

# %%
for i in list_sample_means:
     print(pd.Series(i).mean())
# Out:
# 2.297333333333334
# 2.2696666666666663
# 2.3168888888888888
# 2.3091666666666666
# 2.3005333333333344
# 2.3081111111111094

# %% [markdown]
# ### 8.8 for alone column
# #### 8.8.1 Population Mean and Standard Deviation

# %%
mean_pop_alone = df_num['alone'].mean()
std_pop_alone = df_num['alone'].std()

print("population mean (μ): {}\npopulation standard deviation (σ): {}".format(mean_pop_alone,std_pop_alone))
# Out:
# population mean (μ): 0.6026936026936027
# population standard deviation (σ): 0.4896152299826277

# %% [markdown]
# #### 8.8.2 histplot

# %%
sns.set(rc={'figure.figsize':(12,5)})
sns.histplot(df_num['alone'], kde=True)
# Out:
# <AxesSubplot:xlabel='alone', ylabel='Count'>

# %% [markdown]
# #### 8.8.3 Verifying CLT
# ##### 8.8.3.1 Keeping No. of Samples Constant

# %%
sample_sizes = [(500,3), (500,10), (500,30), (500,50), (500,100), (500,200)]
list_sample_means = []
# Plotting the distribution graphs for the above created Samples
plt.figure(figsize=[15,10])
for ind, (no_of_samples,samp_size) in enumerate(sample_sizes):
     sample_means = [df_num.alone.sample(samp_size).mean() for i in range(no_of_samples)]
     list_sample_means.append(sample_means)
     plt.subplot(2,3,ind+1)
     sns.histplot(sample_means, bins=25, kde=True, stat="density")
     plt.title("No. of Samples: "+str(no_of_samples) + " Sample size: "+str(samp_size))

# %%
for i in list_sample_means:
     print(pd.Series(i).mean())
# Out:
# 0.5880000000000001
# 0.6073999999999998
# 0.6062666666666654
# 0.6041200000000007
# 0.59718
# 0.6038300000000003

# %%
sample_sizes = [(50,30), (100,30), (150,30), (200,30), (250,30), (300,30)]
list_sample_means = []
# Plotting the distribution graphs for the above created Samples
plt.figure(figsize=[15,10])
for ind, (no_of_samples,samp_size) in enumerate(sample_sizes):
     sample_means = [df_num.alone.sample(samp_size).mean() for i in range(no_of_samples)]
     list_sample_means.append(sample_means)
     plt.subplot(2,3,ind+1)
     sns.histplot(sample_means, bins=25, kde=True, stat="density")
     plt.title("No. of Samples: "+str(no_of_samples) + " Sample size: "+str(samp_size))

# %%
for i in list_sample_means:
     print(pd.Series(i).mean())
# Out:
# 0.6093333333333334
# 0.6076666666666669
# 0.6004444444444448
# 0.6050000000000001
# 0.598533333333333
# 0.6092222222222208

# %% [markdown]
# # 9.0 Covariance, Pearson correlation coefficient, Spearman's rank correlation coefficient
# ### 9.1 Covarience

# %%
df_num.cov()
# Out:
#           survived     pclass         age     sibsp     parch         fare  \
# survived  0.236772  -0.137703   -0.441656 -0.018954  0.032017     6.221787
# pclass   -0.137703   0.699015   -3.601855  0.076599  0.012429   -22.830196
# age      -0.441656  -3.601855  169.052400 -3.335345 -1.877987    59.162200
# sibsp    -0.018954   0.076599   -3.335345  1.216043  0.368739     8.748734
# parch     0.032017   0.012429   -1.877987  0.368739  0.649728     8.661052
# fare      6.221787 -22.830196   59.162200  8.748734  8.661052  2469.436846
# class    -0.137703   0.699015   -3.601855  0.076599  0.012429   -22.830196
# alone    -0.048451   0.055347    1.144445 -0.315568 -0.230242    -6.613861
#
#               class     alone
# survived  -0.137703 -0.048451
# pclass     0.699015  0.055347
# age       -3.601855  1.144445
# sibsp      0.076599 -0.315568
# parch      0.012429 -0.230242
# fare     -22.830196 -6.613861
# class      0.699015  0.055347
# alone      0.055347  0.239723

# %% [markdown]
# ### 9.2 Pearson correlation coefficient

# %%
df_num.corr("pearson")
# Out:
#           survived    pclass       age     sibsp     parch      fare  \
# survived  1.000000 -0.338481 -0.069809 -0.035322  0.081629  0.257307
# pclass   -0.338481  1.000000 -0.331339  0.083081  0.018443 -0.549500
# age      -0.069809 -0.331339  1.000000 -0.232625 -0.179191  0.091566
# sibsp    -0.035322  0.083081 -0.232625  1.000000  0.414838  0.159651
# parch     0.081629  0.018443 -0.179191  0.414838  1.000000  0.216225
# fare      0.257307 -0.549500  0.091566  0.159651  0.216225  1.000000
# class    -0.338481  1.000000 -0.331339  0.083081  0.018443 -0.549500
# alone    -0.203367  0.135207  0.179775 -0.584471 -0.583398 -0.271832
#
#              class     alone
# survived -0.338481 -0.203367
# pclass    1.000000  0.135207
# age      -0.331339  0.179775
# sibsp     0.083081 -0.584471
# parch     0.018443 -0.583398
# fare     -0.549500 -0.271832
# class     1.000000  0.135207
# alone     0.135207  1.000000

# %% [markdown]
# ### 9.3 Spearman's rank correlation coefficient

# %%
df_num.corr("spearman")
# Out:
#           survived    pclass       age     sibsp     parch      fare  \
# survived  1.000000 -0.339668 -0.039109  0.088879  0.138266  0.323736
# pclass   -0.339668  1.000000 -0.308875 -0.043019 -0.022801 -0.688032
# age      -0.039109 -0.308875  1.000000 -0.147035 -0.217290  0.118847
# sibsp     0.088879 -0.043019 -0.147035  1.000000  0.450014  0.447113
# parch     0.138266 -0.022801 -0.217290  0.450014  1.000000  0.410074
# fare      0.323736 -0.688032  0.118847  0.447113  0.410074  1.000000
# class    -0.339668  1.000000 -0.308875 -0.043019 -0.022801 -0.688032
# alone    -0.203367  0.135896  0.141379 -0.828215 -0.683719 -0.531472
#
#              class     alone
# survived -0.339668 -0.203367
# pclass    1.000000  0.135896
# age      -0.308875  0.141379
# sibsp    -0.043019 -0.828215
# parch    -0.022801 -0.683719
# fare     -0.688032 -0.531472
# class     1.000000  0.135896
# alone     0.135896  1.000000

# %% [markdown]
# ### 9.4 Pairplot for titanic dataset

# %%
sns.set(rc={'figure.figsize':(25,25)})
sns.pairplot(df_num, height=2.5)

# %% [markdown]
# ### 9.5 Pairplot for titanic dataset with kde

# %%
sns.set(rc={'figure.figsize':(25,25)})
sns.pairplot(df_num, height=2.5,diag_kind="kde")

# %% [markdown]
# # 10.0 Hypothesis testing
# #### 10.1 z-Test

# %%
df_num.head()
# Out:
#    survived  pclass   age  sibsp  parch     fare  class  alone
# 0         0       3  22.0      1      0   7.2500      3      0
# 1         1       1  38.0      1      0  71.2833      1      0
# 2         1       3  26.0      0      0   7.9250      3      1
# 3         1       1  35.0      1      0  53.1000      1      0
# 4         0       3  35.0      0      0   8.0500      3      1

# %%
# population mean

pop_mean_fare=df_num['fare'].mean()
pop_mean_fare
# Out:
# 32.2042079685746

# %%
# population standard deviation

pop_std_fare=df_num['fare'].std()
pop_std_fare
# Out:
# 49.693428597180905

# %%
import random
import math

# %%
# sampling data and calculating sample mean and standard deviation

random.seed(77)
sample_fare=pd.Series(random.sample(list(df_num['fare']), 80))
sample_mean_fare=sample_fare.mean()
sample_mean_fare
# Out:
# 37.59453124999999

# %%
sample_std_fare=sample_fare.std()
sample_std_fare
# Out:
# 66.25722719381305

# %% [markdown]
# #### Question #1
#
# For titanic dataset, the mean of fare is given above(32.2042079685746). A survey is conducted to check the accuracy of
# fares, randomly 80 samples were taken and its mean was found out to be 37.761250000000004.
#
# 1. State null and alternate hypothesis
# 2. with Confidence interval of 95%, Is there is enough evidence to reject the null hypothesis.

# %% [markdown]
# #### Ans
#
# #### Step 1 : Stating hypothesis
#
# 1. Ho = The mean of the fare is accurate.
# 2. H1 = The mean of the fare is not accurate.
#
# The problem is related to two tailed test.
#
#
# #### Step2: Decision Boundary

# %%
CI = 0.95
alpha = 0.05
decision_boundary_lower_fare= -1.96 # from z table for alpha = 0.025, since two tailed test
decision_boundary_upper_fare= 1.96

# %% [markdown]
# #### Step3: Test Statistic

# %%
z_statistic_fare = (sample_mean_fare-pop_mean_fare)/(pop_std_fare/math.sqrt(80))
z_statistic_fare
# Out:
# 0.9701990478999204

# %%
def Hypothesis_checker(db_upper, db_lower, test_statistic):
     if test_statistic > db_lower and test_statistic < db_upper:
        return "Null Hypothesis cannot be rejected"
     else:
        return "Null Hypothesis is rejected"

# %% [markdown]
# #### Step4: Conclusions

# %%
Hypothesis_checker(decision_boundary_upper_fare,decision_boundary_lower_fare,z_statistic_fare)
# Out:
# 'Null Hypothesis cannot be rejected'

# %% [markdown]
# ## 10.2 t-Test

# %%
# sampling data and calculating sample mean and standard deviation

random.seed(7)
sample_fare1=pd.Series(random.sample(list(df_num['fare']), 25))
sample_mean_fare1=sample_fare.mean()
sample_mean_fare1
# Out:
# 37.59453124999999

# %%
sample_std_fare1=sample_fare.std()
sample_std_fare1
# Out:
# 66.25722719381305

# %% [markdown]
# #### Question #2
# For titanic dataset, the mean of fare is given above(32.2042079685746). A survey is conducted to check the accuracy of
# fares, randomly 25 samples were taken and its mean was found out to be 37.59453124999999 and standard deviation is
# 66.25722719381305.
# 1. State null and alternate hypothesis
# 2. with Confidence interval of 95%, Is there is enough evidence to reject the null hypothesis

# %% [markdown]
# #### Ans:
# 1. since n<30 and sample standard deviation is given, hence using t-Test. It is two tailed test.
#
# #### Step1: Stating Hypothesis
#
# 1. Ho = The mean of the fare is accurate.
# 2. h1 = The mean of the fare is not accurate.
#
# The problem is related to two tailed test.
#
# #### Step2: Decision Boundary

# %%
total_sample_size_fare1 = 25
CI = 0.95
alpha = 0.05
dof_t = 24 # degree of freedom is no of samples minus one.
decision_boundary_lower_fare1= -2.064 # from t table for alpha = 0.025 (since two tailed test) and dof = 24.
decision_boundary_upper_fare1= 2.064

# %% [markdown]
# #### Step3: Test Statistic

# %%
t_statistic_fare1 = (sample_mean_fare1-pop_mean_fare)/(sample_std_fare1/math.sqrt(total_sample_size_fare1))
t_statistic_fare1
# Out:
# 0.40677247673358147

# %% [markdown]
# #### Step4: Conclusions

# %%
Hypothesis_checker(decision_boundary_upper_fare1,decision_boundary_lower_fare1,t_statistic_fare1)
# Out:
# 'Null Hypothesis cannot be rejected'

# %% [markdown]
# ## 10.3 z-Test with Proportions

# %%
# counting third class passenger

count_third_class=df_num[df_num['pclass'] == 3]['pclass'].count()
count_third_class
# Out:
# 491

# %%
# counting total passenger

population_count = df_num['pclass'].count()
population_count
# Out:
# 891

# %%
# calculating percentage of third class passenger

percent_third_class= count_third_class/population_count
percent_third_class
# Out:
# 0.5510662177328844

# %%
# sampling data and calculating sample mean and standard deviation

random.seed(89)
sample_pclass=pd.Series(random.sample(list(df['pclass']), 300))
count_third_sample= 0

# %%
for i in sample_pclass:
    if i == 3:
        count_third_sample += 1
count_third_sample
# Out:
# 308

# %% [markdown]
# #### Question #3
# For titanic dataset, it is belived that arount 55 percent passangers travelled in third class. A survey is conducted to check
# this fact, randomly 300 samples were taken and it was found that 154 passengers travelled by third class.
#
# 1. State null and alternate hypothesis
# 2. with Confidence interval of 95%, Is there is enough evidence to reject the null hypothesis.
#
# #### Ans:

# %%
total_sample_count_third_class = 300
Po = percent_third_class #i.e 55 percent, null hypothesis value
Po
# Out:
# 0.5510662177328844

# %%
# observed value

P= count_third_sample/total_sample_count_third_class
P
# Out:
# 0.5133333333333333

# %% [markdown]
# #### Step1: Stating Hypothesis
#
# 1. Ho = Passengers travelled by third class is equal to 55 percent
# 2. h1 = Passengers travelled by third class is not equal to 55 percent
#
# The problem is related to two tailed test.
#
# #### Step2: Decision Boundary

# %%
CI = 0.95
alpha = 0.05
decision_boundary_lower_pclass= -1.96 # from z table for alpha = 0.025, since two tailed test
decision_boundary_upper_pclass= 1.96

# %% [markdown]
# #### Step3: Test Statistic

# %%
z_statistic_pclass = (P-Po)/math.sqrt(Po*(1-Po)/total_sample_count_third_class)
z_statistic_pclass
# Out:
# -1.313976489852826

# %% [markdown]
# #### Step4: Conclusion

# %%
Hypothesis_checker(decision_boundary_upper_pclass,decision_boundary_lower_pclass,z_statistic_pclass)
# Out:
# 'Null Hypothesis cannot be rejected'

# %% [markdown]
# ## 10.4 Chi-Square test

# %%
# class wise passenger percentage

data_expected = {'First_class_percent': [24], 'Second_class_percent': [21], 'Third_class_percent': [55]}

# %%
# data is given in percentage

df_pclass_expected = pd.DataFrame(data = data_expected)

# %%
# sampling data and calculating passenger count class-wise

random.seed(101)
sample_pclass_chi_square=pd.Series(random.sample(list(df['pclass']), 500))

# %%
data_sample = {'First_class_count': [129], 'Second_class_count': [102], 'Third_class_count': [269]}

# %%
df_pclass_sample = pd.DataFrame(data = data_sample)

# %% [markdown]
# #### Question #4
# For titanic incident, after the sinking of ship passengers were sorted based on class and same is given in table #1 below.
# after some time a study was conducted to cross verify this data and sample of 500 records was taken and its observation is
# given in table #2 below.
#
# 1. State null and alternate hypothesis
# 2. with Confidence interval of 95%, Is there is enough evidence to verify the accuracy of data.
#
# #### Ans:

# %%
# table 1: class-wise passenger data in percentage

df_pclass_expected
# Out:
#    First_class_percent  Second_class_percent  Third_class_percent
# 0                   24                    21                   55

# %%
# table :2 observed class-wise passenger count from sample

df_pclass_sample
# Out:
#    First_class_count  Second_class_count  Third_class_count
# 0                129                 102                269

# %%
#now calculate expected value from given percentage and no of samples and making a list having tuple of obser
#expected value

list_chi_square = [(129, 0.24*500), (102, 0.21*500), (269, 0.55*500)]
list_chi_square
# Out:
# [(129, 120.0), (102, 105.0), (269, 275.0)]

# %% [markdown]
# #### Step1: Stating Hypothesis
#
# 1. Ho = Passengers class data is accurate.
# 2. H1 = Passengers class data is not accurate.
#
# #### Step2: Decision Boundary

# %%
 CI = 0.95
alpha = 0.05
dof = 2 # degree of freedom = no, of category minus 1(here there are 3 classes)
decision_boundary_chi_square = 5.991 # from chi-square table for alpha = 0.05 and dof = 2

# %% [markdown]
# #### Step3: Test Statistic

# %%
def chi_square_statistic_func(list_data):
    global chi_square_statistic
    chi_square_statistic = 0
    for observed, expected in list_data:
        value = ((observed-expected)**2/expected)
        chi_square_statistic += value
    return chi_square_statistic
print("chi_square_statistic value is: ", chi_square_statistic_func(list_chi_square))
chi_square_statistic
# Out:
# chi_square_statistic value is:  0.8916233766233768
# 0.8916233766233768

# %% [markdown]
# #### Step4: Conclusion

# %%
def hypothesis_checker_chi_square_test(decision_boundary, test_statistic):
     if test_statistic > decision_boundary:
        return "Null Hypothesis is rejected"
     else:
        return "Null Hypothesis cannot be rejected"

# %%
hypothesis_checker_chi_square_test(decision_boundary_chi_square, chi_square_statistic)
# Out:
# 'Null Hypothesis cannot be rejected'

# %% [markdown]
# ## Note: All null hypothesis will be accepted since the
# ## samples are collected from the same dataset(No Survey)
