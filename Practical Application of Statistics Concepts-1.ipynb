# %% [markdown]
# # Practical Application of Statistics Concepts
# - Measure of Central Tendency,
# - Measure of Dispersion,
# - 5 number summary,
# - BoxPlot,
# - Histogram,
# - Standization,
# - Normalization,
# - Central Limit Theorem,
# - Covariance,
# - Pearson correlation coefficient,
# - Spearman's rank correlation coefficient

# %%
import numpy as np
import seaborn as sns
import statistics as stat
import matplotlib.pyplot as plt
import random

# %% [markdown]
# ## 0.0 Tips dataset

# %%
df = sns.load_dataset("tips")

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %% [markdown]
# Finding out the numeric columns

# %%
df_num = df[df.dtypes[df.dtypes != 'category'].index]
df_num.head()
# Out:
#    total_bill   tip  size
# 0       16.99  1.01     2
# 1       10.34  1.66     3
# 2       21.01  3.50     3
# 3       23.68  3.31     2
# 4       24.59  3.61     4

# %% [markdown]
# ## 1.0 Measure of Central Tendency

# %% [markdown]
# ### 1.1 mean of all numeric columns

# %%
np.mean(df_num, axis=0)
# Out:
# total_bill    19.785943
# tip            2.998279
# size           2.569672
# dtype: float64

# %% [markdown]
# ### 1.2 median of all numeric columns

# %%
np.median(df_num, axis=0)
# Out:
# array([17.795,  2.9  ,  2.   ])

# %% [markdown]
# ### 1.3 mode of all columns

# %%
stat.mode(df['total_bill'])
# Out:
# 13.42

# %%
stat.mode(df['tip'])
# Out:
# 2.0

# %%
stat.mode(df['sex'])
# Out:
# 'Male'

# %%
stat.mode(df['smoker'])
# Out:
# 'No'

# %%
stat.mode(df['day'])
# Out:
# 'Sat'

# %%
stat.mode(df['time'])
# Out:
# 'Dinner'

# %%
stat.mode(df['size'])
# Out:
# 2

# %% [markdown]
# ## 2.0 Measure of Dispersion

# %% [markdown]
# #### 2.1 Variance

# %%
stat.variance(df_num['total_bill'])
# Out:
# 79.25293861397827

# %%
stat.variance(df_num['tip'])
# Out:
# 1.9144546380624705

# %%
stat.variance(df_num['size'])
# Out:
# 0.9045908385616946

# %% [markdown]
# ### 2.2 Standard Deviation

# %%
stat.stdev(df_num['total_bill'])
# Out:
# 8.902411954856856

# %%
stat.stdev(df_num['tip'])
# Out:
# 1.383638189001182

# %%
stat.stdev(df_num['size'])
# Out:
# 0.9510998047322345

# %% [markdown]
# ## 3.0 Five Numbers summary

# %% [markdown]
# #### 3.1 For total_bill Column

# %%
df_num['total_bill'].min() # zeroth Percentile or minimum value
# Out:
# 3.07

# %%
np.percentile(df_num['total_bill'], 25) # 1st quartile
# Out:
# 13.3475

# %%
np.percentile(df_num['total_bill'], 50) # 2nd quartile or median
# Out:
# 17.795

# %%
np.percentile(df_num['total_bill'], 75) # 3rd quartile
# Out:
# 24.127499999999998

# %%
df_num['total_bill'].max() # 100th Percentile or maximum value
# Out:
# 50.81

# %% [markdown]
# #### 3.2 For tip Column

# %%
df_num['tip'].min() # zeroth Percentile or minimum value
# Out:
# 1.0

# %%
np.percentile(df_num['tip'], 25) # 1st quartile
# Out:
# 2.0

# %%
np.percentile(df_num['tip'], 50) # 2nd quartile or median
# Out:
# 2.9

# %%
np.percentile(df_num['tip'], 75) # 3rd quartile
# Out:
# 3.5625

# %%
df_num['tip'].max() # 100th Percentile or maximum value
# Out:
# 10.0

# %% [markdown]
# #### 3.3 For size Column

# %%
df_num['size'].min() # zeroth Percentile or minimum value
# Out:
# 1

# %%
np.percentile(df_num['size'], 25) # 1st quartile
# Out:
# 2.0

# %%
np.percentile(df_num['size'], 50) # 2nd quartile or median
# Out:
# 2.0

# %%
np.percentile(df_num['size'], 75) # 3rd quartile
# Out:
# 3.0

# %%
df_num['size'].max() # 100th Percentile or maximum value
# Out:
# 6

# %% [markdown]
# ## 4.0 Box Plot

# %% [markdown]
# ### 4.1 Box plot for total_bill

# %%
sns.set(rc={'figure.figsize':(15,5)})
sns.boxplot(data = df_num['total_bill'], orient="h")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 4.2 Box plot for tip

# %%
sns.set(rc={'figure.figsize':(15,5)})
sns.boxplot(data = df_num['tip'], orient="h")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 4.3 Box plot for size

# %%
sns.set(rc={'figure.figsize':(15,5)})
sns.boxplot(data = df_num['size'], orient="h")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 4.4 Box plot combined

# %%
sns.set(rc={'figure.figsize':(15,8)})
sns.boxplot(data = df_num, orient="v")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 5.0 Histogram and Distribution

# %% [markdown]
# ### 5.1 Histogram and distribution for total_bill

# %%
sns.histplot(df_num['total_bill'], kde=True)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %% [markdown]
# ### 5.2 Histogram and distribution for tip

# %%
sns.histplot(df_num['tip'], kde=True, bins=10)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Count'>

# %% [markdown]
# ### 5.3 Histogram and distribution for size

# %%
sns.histplot(df_num['size'], kde=True, bins=5)
# Out:
# <AxesSubplot:xlabel='size', ylabel='Count'>

# %% [markdown]
# ## 6.0 Standardization

# %%
df_num.head()
# Out:
#    total_bill   tip  size
# 0       16.99  1.01     2
# 1       10.34  1.66     3
# 2       21.01  3.50     3
# 3       23.68  3.31     2
# 4       24.59  3.61     4

# %% [markdown]
# ### 6.1 standardization of dataset

# %%
df_num_std = (df_num - df_num.mean())/df_num.std()
df_num_std.head()
# Out:
#    total_bill       tip      size
# 0   -0.314066 -1.436993 -0.598961
# 1   -1.061054 -0.967217  0.452453
# 2    0.137497  0.362610  0.452453
# 3    0.437416  0.225291 -0.598961
# 4    0.539635  0.442111  1.503867

# %% [markdown]
# ### 6.2 mean and standard deviation of standardized dataset

# %%
round(df_num_std.mean(), 2)
# Out:
# total_bill   -0.0
# tip          -0.0
# size         -0.0
# dtype: float64

# %%
df_num_std.std()
# Out:
# total_bill    1.0
# tip           1.0
# size          1.0
# dtype: float64

# %% [markdown]
# ### 6.3 kde plot of original dataset

# %%
sns.kdeplot(data = df_num) # kde plot for numeric data
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ### 6.4 kde plot of standardized dataset

# %%
sns.kdeplot(data = df_num_std) # kde plot for numeric data in tips data set after standardization
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ## 7.0 Normalization
# #### Using MinMax Scalar
# Note: using MinMax Scalar the data range will be 0 to 1.

# %%
df_num.head()
# Out:
#    total_bill   tip  size
# 0       16.99  1.01     2
# 1       10.34  1.66     3
# 2       21.01  3.50     3
# 3       23.68  3.31     2
# 4       24.59  3.61     4

# %% [markdown]
# ### 7.1 normalization of dataset

# %%
df_num_normal = (df_num - df_num.min()) / (df_num.max() - df_num.min())
df_num_normal.head()
# Out:
#    total_bill       tip  size
# 0    0.291579  0.001111   0.2
# 1    0.152283  0.073333   0.4
# 2    0.375786  0.277778   0.4
# 3    0.431713  0.256667   0.2
# 4    0.450775  0.290000   0.6

# %% [markdown]
# ### 7.2 min, max, mean and standard deviation of normalized dataset

# %%
df_num_normal.min() # minimum value of data
# Out:
# total_bill    0.0
# tip           0.0
# size          0.0
# dtype: float64

# %%
df_num_normal.max() # maximum value of data
# Out:
# total_bill    1.0
# tip           1.0
# size          1.0
# dtype: float64

# %%
df_num_normal.mean()
# Out:
# total_bill    0.350145
# tip           0.222031
# size          0.313934
# dtype: float64

# %%
df_num_normal.std()
# Out:
# total_bill    0.186477
# tip           0.153738
# size          0.190220
# dtype: float64

# %% [markdown]
# ### 7.3 kde plot of original dataset

# %%
sns.kdeplot(data = df_num) # kde plot for numeric data
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ### 7.4 kde plot of normalized dataset

# %%
sns.kdeplot(data = df_num_normal) # kde plot for numeric data in tips data set after normalization
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ## 8.0 Central Limit Theorem

# %%
df_num.head()
# Out:
#    total_bill   tip  size
# 0       16.99  1.01     2
# 1       10.34  1.66     3
# 2       21.01  3.50     3
# 3       23.68  3.31     2
# 4       24.59  3.61     4

# %% [markdown]
# ### 8.1 for total_bill

# %%
mean_pop_total_bill = df_num['total_bill'].mean()
std_pop_total_bill = df_num['total_bill'].std()


print("population mean (μ): {}\npopulation standard deviation (σ): {}".format(mean_pop_total_bill,std_pop_total_bill))
# Out:
# population mean (μ): 19.785942622950824
# population standard deviation (σ): 8.902411954856856

# %%
sns.set(rc={'figure.figsize':(12,5)})
sns.histplot(df_num['total_bill'], kde=True)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
def mean_distribution(data, samples_count, data_points_count):
    list_sample = list()
    data = np.array(data.values)
    for i in range(0, samples_count):
        samples = random.sample(range(0, data.shape[0]), data_points_count)
        list_sample.append(data[samples].mean())
    return np.array(list_sample)

count = 0
mean_list = list()
fg, ax = plt.subplots(nrows=2, ncols=2, figsize=(15, 15))
lst = [(10,50),(20,50),(30,50),(50,50)]
for i in (0,1):
    for j in (0,1):
        ax[i,j].set_title("sample of " + str(lst[count][0]) + " having " + str(lst[count][1])+" no. of data points")
        sns.histplot(mean_distribution(df_num['total_bill'], lst[count][0],lst[count][1]),ax = ax[i,j], bins = 10, kde=True)
        mean_list.append(mean_distribution(df_num['total_bill'], lst[count][0],lst[count][1]))
        count +=1

# %% [markdown]
# ### 8.2 for tip

# %%
mean_pop_tip = df_num['tip'].mean()
std_pop_tip= df_num['tip'].std()

print("population mean (μ): {}\npopulation standard deviation (σ): {}".format(mean_pop_tip,std_pop_tip))
# Out:
# population mean (μ): 2.9982786885245902
# population standard deviation (σ): 1.3836381890011826

# %%
sns.set(rc={'figure.figsize':(12,5)})
sns.histplot(df_num['tip'], kde=True)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Count'>

# %%
def mean_distribution(data, samples_count, data_points_count):
    list_sample = list()
    data = np.array(data.values)
    for i in range(0, samples_count):
        samples = random.sample(range(0, data.shape[0]), data_points_count)
        list_sample.append(data[samples].mean())
    return np.array(list_sample)

count = 0
mean_list = list()
fg, ax = plt.subplots(nrows=2, ncols=2, figsize=(15, 15))
lst = [(10,50),(20,50),(30,50),(50,50)]
for i in (0,1):
    for j in (0,1):
        ax[i,j].set_title("sample of " + str(lst[count][0]) + " having " + str(lst[count][1])+" no. of data points")
        sns.histplot(mean_distribution(df_num['tip'], lst[count][0],lst[count][1]),ax = ax[i,j],bins=10, kde=True)
        mean_list.append(mean_distribution(df_num['tip'], lst[count][0],lst[count][1]))
        count +=1

# %% [markdown]
# ### 8.3 for size

# %%
mean_pop_size = df_num['size'].mean()
std_pop_size = df_num['size'].std()
print("population mean (μ): {}\npopulation standard deviation (σ): {}".format(mean_pop_size,std_pop_size))
# Out:
# population mean (μ): 2.569672131147541
# population standard deviation (σ): 0.9510998047322332

# %%
sns.set(rc={'figure.figsize':(12,5)})
sns.histplot(df_num['size'], kde=True)
# Out:
# <AxesSubplot:xlabel='size', ylabel='Count'>

# %%
def mean_distribution(data, samples_count, data_points_count):
    list_sample = list()
    data = np.array(data.values)
    for i in range(0, samples_count):
        samples = random.sample(range(0, data.shape[0]), data_points_count)
        list_sample.append(data[samples].mean())
    return np.array(list_sample)
    
count = 0
mean_list = list()
fg, ax = plt.subplots(nrows=2, ncols=2, figsize=(15, 15))
lst = [(10,50),(20,50),(30,50),(50,50)]
for i in (0,1):
    for j in (0,1):
        ax[i,j].set_title("sample of " + str(lst[count][0]) + " having " + str(lst[count][1])+" no. of data points")
        sns.histplot(mean_distribution(df_num['size'], lst[count][0],lst[count][1]),ax = ax[i,j], bins=10, kde=True)
        mean_list.append(mean_distribution(df_num['size'], lst[count][0],lst[count][1]))
        count +=1

# %% [markdown]
# ## 9.0 Covariance, Pearson correlation coefficient, Spearman's rank correlation coefficient

# %% [markdown]
# ### 9.1 Covarience

# %%
df_num.cov()
# Out:
#             total_bill       tip      size
# total_bill   79.252939  8.323502  5.065983
# tip           8.323502  1.914455  0.643906
# size          5.065983  0.643906  0.904591

# %% [markdown]
# ### 9.2 Pearson correlation coefficient

# %%
df_num.corr("pearson")
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %% [markdown]
# ### 9.3 Spearman's rank correlation coefficient

# %%
df_num.corr("spearman")
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.678968  0.604791
# tip           0.678968  1.000000  0.468268
# size          0.604791  0.468268  1.000000

# %% [markdown]
# ### 9.4 Pairplot for tips dataset

# %%
sns.set(rc={'figure.figsize':(15,15)})
sns.pairplot(df_num, height=5)

# %% [markdown]
# ### 9.4 Pairplot for tips dataset with kde

# %%
sns.set(rc={'figure.figsize':(15,15)})
sns.pairplot(df_num, diag_kind="kde", height=5)
